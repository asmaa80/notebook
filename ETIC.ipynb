# %% [markdown]
# # Températures du bâtiment à Lyon

# %%
"Date du début" et  "Date de fin" ,lyon
# Out:
#       Etage       Dates
# 0    PP_213  2020-05-11
# 1  UCPA_101  2020-05-11
# 2  UCPA_111  2020-05-11
#       Etage       Dates
# 0    PP_213  2020-09-30
# 1  UCPA_101  2020-09-30
# 2  UCPA_111  2020-09-30

# %%
'Moyenne, minimum, maximum de degrés Celsius, jour (8h_20h), Lyon' et
'Moyenne, Maximum, Minimum de Celsius, nuit (20h_8h), Lyon'
# Out:
# <div>                            <div id="54c65b57-bfe3-4290-bd83-7486ae1e5ca5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("54c65b57-bfe3-4290-bd83-7486ae1e5ca5")) {                    Plotly.newPlot(                        "54c65b57-bfe3-4290-bd83-7486ae1e5ca5",                        [{"name": "avg", "type": "bar", "x": ["PP_213", "UCPA_101", "UCPA_111"], "y": [27.37076023391813, 27.35744047619048, 26.7]}, {"name": "max", "type": "bar", "x": ["PP_213", "UCPA_101", "UCPA_111"], "y": [34.5, 34.0, 32.5]}, {"name": "min", "type": "bar", "x": ["PP_213", "UCPA_101", "UCPA_111"], "y": [21.0, 21.5, 17.5]}],                        {"barmode": "group", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "mark
# ...

# %%
'API et Celsius tout le période de travailler jour par jour, Lyon'
# Out:
# <div>                            <div id="bf4f504a-94b9-4021-a20c-017b4554c370" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bf4f504a-94b9-4021-a20c-017b4554c370")) {                    Plotly.newPlot(                        "bf4f504a-94b9-4021-a20c-017b4554c370",                        [{"name": "Celsius", "type": "bar", "x": ["2020-05-11", "2020-05-12", "2020-05-13", "2020-05-14", "2020-05-15", "2020-05-16", "2020-05-17", "2020-05-18", "2020-05-19", "2020-05-20", "2020-05-21", "2020-05-22", "2020-05-23", "2020-05-24", "2020-05-25", "2020-05-26", "2020-05-27", "2020-05-28", "2020-05-29", "2020-05-30", "2020-05-31", "2020-06-01", "2020-06-02", "2020-06-03", "2020-06-04", "2020-06-05", "2020-06-06", "2020-06-07", "2020-06-08", "2020-06-09", "2020-
# ...

# %%
"nb val_Celsius" et "nb val_Celsius" et ="nbval(Celsius)>28 , jour (8h_20h)", Lyon
# Out:
# <div>                            <div id="a4d09013-b368-474d-8c8f-967a846a282d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4d09013-b368-474d-8c8f-967a846a282d")) {                    Plotly.newPlot(                        "a4d09013-b368-474d-8c8f-967a846a282d",                        [{"alignmentgroup": "True", "hovertemplate": "Etage=%{x}<br>count=%{text}<extra></extra>", "legendgroup": "PP_213", "marker": {"color": "#636efa"}, "name": "PP_213", "offsetgroup": "PP_213", "orientation": "v", "showlegend": true, "text": [3417.0], "textposition": "auto", "type": "bar", "x": ["PP_213"], "xaxis": "x", "y": [3417], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Etage=%{x}<br>count=%{text}<extra></extra>", "legendgroup": "UCPA_101", "mar
# ...

# %%
'Moyenne Taux d’inconfort(Celsius), Lyon(Année)'
# Out:
# <div>                            <div id="1ae8d9a1-dc5b-40c3-a039-ae6ee910a23f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ae8d9a1-dc5b-40c3-a039-ae6ee910a23f")) {                    Plotly.newPlot(                        "1ae8d9a1-dc5b-40c3-a039-ae6ee910a23f",                        [{"name": "UCPA_101", "type": "bar", "x": ["% nb val >28", "% nb val >29", "% nb val >30", "% nb val >31"], "y": [16, 11, 5, 2]}, {"name": "UCPA_111", "type": "bar", "x": ["% nb val >28", "% nb val >29", "% nb val >30", "% nb val >31"], "y": [14, 8, 4, 2]}, {"name": "PP_213", "type": "bar", "x": ["% nb val >28", "% nb val >29", "% nb val >30", "% nb val >31"], "y": [16, 12, 6, 3]}],                        {"barmode": "group", "template": {"data": {"bar": [{"error_
# ...

# %%
'Moyenne Taux d’inconfort(Celsius), Lyon(été)'
# Out:
# <div>                            <div id="3776b19a-6df5-43c0-8137-727861fe781d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3776b19a-6df5-43c0-8137-727861fe781d")) {                    Plotly.newPlot(                        "3776b19a-6df5-43c0-8137-727861fe781d",                        [{"name": "UCPA_101", "type": "bar", "x": ["% nb val >28", "% nb val >29", "% nb val >30", "% nb val >31"], "y": [41, 28, 14, 6]}, {"name": "UCPA_111", "type": "bar", "x": ["% nb val >28", "% nb val >29", "% nb val >30", "% nb val >31"], "y": [35, 21, 12, 4]}, {"name": "PP_213", "type": "bar", "x": ["% nb val >28", "% nb val >29", "% nb val >30", "% nb val >31"], "y": [41, 31, 15, 8]}],                        {"barmode": "group", "template": {"data": {"bar": [{"er
# ...

# %%
'Moyenne, Maximum, Minimum de Celsius, (11/05 - 31/05), jour (8h-20h), Lyon' et
'Moyenne, Maximum, Minimum de Celsius, (11/05 - 31/05), nuit (20h-8h), Lyon'
# Out:
# <div>                            <div id="07de6fc6-cebb-4fbe-b18f-0e4c4c5e609a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07de6fc6-cebb-4fbe-b18f-0e4c4c5e609a")) {                    Plotly.newPlot(                        "07de6fc6-cebb-4fbe-b18f-0e4c4c5e609a",                        [{"name": "avg", "type": "bar", "x": ["PP_213", "UCPA_101", "UCPA_111"], "y": [23.925087108013937, 24.930357142857144, 23.13588850174216]}, {"name": "max", "type": "bar", "x": ["PP_213", "UCPA_101", "UCPA_111"], "y": [26.5, 27.5, 26.0]}, {"name": "min", "type": "bar", "x": ["PP_213", "UCPA_101", "UCPA_111"], "y": [21.0, 22.0, 17.5]}],                        {"barmode": "group", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#
# ...

# %%
'Moyenne, Maximum, Minimum de Celsius, (01/06 - 30/06),jour(8h-20h),lyon' et
'Moyenne, Maximum, Minimum de Celsius, (01/06 - 30/06),nuit(20h-8h),lyon'
# Out:
# <div>                            <div id="7c8041a0-4b1a-4f51-b075-d19d454d7795" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c8041a0-4b1a-4f51-b075-d19d454d7795")) {                    Plotly.newPlot(                        "7c8041a0-4b1a-4f51-b075-d19d454d7795",                        [{"name": "avg", "type": "bar", "x": ["PP_213", "UCPA_101", "UCPA_111"], "y": [25.91211401425178, 26.089285714285715, 24.756532066508317]}, {"name": "max", "type": "bar", "x": ["PP_213", "UCPA_101", "UCPA_111"], "y": [30.5, 31.0, 29.5]}, {"name": "min", "type": "bar", "x": ["PP_213", "UCPA_101", "UCPA_111"], "y": [22.5, 22.0, 21.5]}],                        {"barmode": "group", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#
# ...

# %%
'Moyenne, Maximum, Minimum de Celsius, (01/07 - 31/07), jour (8h-20h), Lyon' et
'Moyenne, Maximum, Minimum de Celsius, (01/07 - 31/07), nuit (20h-8h), Lyon'
# Out:
# <div>                            <div id="9da5b98d-fb8b-43f3-96e5-9b54ce075668" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9da5b98d-fb8b-43f3-96e5-9b54ce075668")) {                    Plotly.newPlot(                        "9da5b98d-fb8b-43f3-96e5-9b54ce075668",                        [{"name": "avg", "type": "bar", "x": ["PP_213", "UCPA_101", "UCPA_111"], "y": [28.65437788018433, 28.846774193548388, 28.36290322580645]}, {"name": "max", "type": "bar", "x": ["PP_213", "UCPA_101", "UCPA_111"], "y": [34.5, 33.5, 32.5]}, {"name": "min", "type": "bar", "x": ["PP_213", "UCPA_101", "UCPA_111"], "y": [24.5, 25.0, 25.0]}],                        {"barmode": "group", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2
# ...

# %%
'Moyenne, Maximum, Minimum de Celsius, (01/08 - 31/08), jour (8h-20h), Lyon' et
'Moyenne, Maximum, Minimum de Celsius, (01/08 - 31/08), nuit (20h-8h), Lyon'
# Out:
# <div>                            <div id="823421f9-7253-4bfd-bd7c-b0cc416b76b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("823421f9-7253-4bfd-bd7c-b0cc416b76b5")) {                    Plotly.newPlot(                        "823421f9-7253-4bfd-bd7c-b0cc416b76b5",                        [{"name": "avg", "type": "bar", "x": ["PP_213", "UCPA_101", "UCPA_111"], "y": [30.21082949308756, 29.351382488479263, 29.61290322580645]}, {"name": "max", "type": "bar", "x": ["PP_213", "UCPA_101", "UCPA_111"], "y": [33.5, 34.0, 32.5]}, {"name": "min", "type": "bar", "x": ["PP_213", "UCPA_101", "UCPA_111"], "y": [25.0, 23.5, 24.0]}],                        {"barmode": "group", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2
# ...

# %%
'Moyenne, Maximum, Minimum de Celsius, (01/09 - 30/09), jour (8h-20h), Lyon' et
'Moyenne, Maximum, Minimum de Celsius, (01/09 - 30/09), nuit (20h08h), Lyon'
# Out:
# <div>                            <div id="c13adcb3-ca58-4c44-b3c9-0cdd64ecedf4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c13adcb3-ca58-4c44-b3c9-0cdd64ecedf4")) {                    Plotly.newPlot(                        "c13adcb3-ca58-4c44-b3c9-0cdd64ecedf4",                        [{"name": "avg", "type": "bar", "x": ["PP_213", "UCPA_101", "UCPA_111"], "y": [26.982142857142858, 26.811904761904763, 26.37857142857143]}, {"name": "max", "type": "bar", "x": ["PP_213", "UCPA_101", "UCPA_111"], "y": [30.5, 31.5, 30.5]}, {"name": "min", "type": "bar", "x": ["PP_213", "UCPA_101", "UCPA_111"], "y": [22.0, 21.5, 21.0]}],                        {"barmode": "group", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#
# ...

# %% [markdown]
# # Températures du bâtiment à Grenoble

# %%
"Date du début" et  "Date de fin" ,Grenoble
# Out:
#                Eta Ge Date Du Dé But
# 0         COOP_CWK_R1       03/07/20
# 1     COOP_Cuisine_R1       10/10/20
# 2     COOP_ENERC_MEZZ       03/07/20
# 3     COOP_ENERC_URSC       03/07/20
# 4        COOP_ENER_R2       03/07/20
# 5  COOP_Penishe_R1_su       03/07/20
#                Eta Ge Date De Fin
# 0         COOP_CWK_R1    30/03/21
# 1     COOP_Cuisine_R1    30/03/21
# 2     COOP_ENERC_MEZZ    22/03/21
# 3     COOP_ENERC_URSC    03/10/20
# 4        COOP_ENER_R2    30/03/21
# 5  COOP_Penishe_R1_su    29/03/21

# %%
'Moyenne, minimum, maximum de Celsius, jour (8h_20h), Lyon' et
'Moyenne, Maximum, Minimum de Celsius, nuit (20h_8h), Lyon'
# Out:
# <div>                            <div id="6b334841-5df6-4433-8a96-c14e7093dfc0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b334841-5df6-4433-8a96-c14e7093dfc0")) {                    Plotly.newPlot(                        "6b334841-5df6-4433-8a96-c14e7093dfc0",                        [{"name": "avg", "type": "bar", "x": ["COOP_CWK_R1", "COOP_Cuisine_R1", "COOP_ENERC_MEZZ", "COOP_ENERC_URSC", "COOP_ENER_R2", "COOP_Penishe_R1_su"], "y": [22.43465209359606, 20.45874908736919, 22.00278485041375, 25.557329136690647, 20.79813760197014, 21.99086969978335]}, {"name": "max", "type": "bar", "x": ["COOP_CWK_R1", "COOP_Cuisine_R1", "COOP_ENERC_MEZZ", "COOP_ENERC_URSC", "COOP_ENER_R2", "COOP_Penishe_R1_su"], "y": [30.0, 25.0, 35.5, 33.0, 31.5, 29.5]}, {"na
# ...

# %%
'API et Celsius tout le période de travailler jour par jour,Grenoble'
# Out:
# <div>                            <div id="cdb439b4-1c72-422f-86a1-77d6cdd11e8f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cdb439b4-1c72-422f-86a1-77d6cdd11e8f")) {                    Plotly.newPlot(                        "cdb439b4-1c72-422f-86a1-77d6cdd11e8f",                        [{"name": "Celsius", "type": "bar", "x": ["2020-07-03", "2020-07-04", "2020-07-05", "2020-07-06", "2020-07-07", "2020-07-08", "2020-07-09", "2020-07-10", "2020-07-11", "2020-07-12", "2020-07-13", "2020-07-14", "2020-07-15", "2020-07-16", "2020-07-17", "2020-07-18", "2020-07-19", "2020-07-20", "2020-07-21", "2020-07-22", "2020-07-23", "2020-07-24", "2020-07-25", "2020-07-26", "2020-07-27", "2020-07-28", "2020-07-29", "2020-07-30", "2020-07-31", "2020-08-01", "2020-
# ...

# %%
"nb val_Celsius" et "nbval(Celsius)>28" et "nbval(Celsius)>28 , jour (8h_20h)" ,Grenoble
# Out:
# <div>                            <div id="577c1b24-75be-4fe9-9489-dae26d8a2a9b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("577c1b24-75be-4fe9-9489-dae26d8a2a9b")) {                    Plotly.newPlot(                        "577c1b24-75be-4fe9-9489-dae26d8a2a9b",                        [{"alignmentgroup": "True", "hovertemplate": "Etage=%{x}<br>count=%{text}<extra></extra>", "legendgroup": "COOP_CWK_R1", "marker": {"color": "#636efa"}, "name": "COOP_CWK_R1", "offsetgroup": "COOP_CWK_R1", "orientation": "v", "showlegend": true, "text": [12976.0], "textposition": "auto", "type": "bar", "x": ["COOP_CWK_R1"], "xaxis": "x", "y": [12976], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Etage=%{x}<br>count=%{text}<extra></extra>", "legendgr
# ...

# %%
'Moyenne_Taux d’inconfort(Celsius),Grenoble(Année)'
# Out:
# <div>                            <div id="bcc78355-4234-4768-8b91-8212c7c118b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bcc78355-4234-4768-8b91-8212c7c118b0")) {                    Plotly.newPlot(                        "bcc78355-4234-4768-8b91-8212c7c118b0",                        [{"name": "COOP_Cuisine_R11", "type": "bar", "x": ["% nb val >28", "% nb val >29", "% nb val >30", "% nb val >31"], "y": [0, 0, 0, 0]}, {"name": "COOP_CWK_R1", "type": "bar", "x": ["% nb val >28", "% nb val >29", "% nb val >30", "% nb val >31"], "y": [3, 1, 0, 0]}, {"name": "COOP_ENERC_MEZZ", "type": "bar", "x": ["% nb val >28", "% nb val >29", "% nb val >30", "% nb val >31"], "y": [9, 5, 2, 1]}, {"name": "COOP_ENERC_URSC", "type": "bar", "x": ["% nb val >28", "% 
# ...

# %%
'Moyenne_Taux d’inconfort(Celsius),Grenoble(été)'
# Out:
# <div>                            <div id="647c2607-b04f-4978-88c0-9eec37ebb24d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("647c2607-b04f-4978-88c0-9eec37ebb24d")) {                    Plotly.newPlot(                        "647c2607-b04f-4978-88c0-9eec37ebb24d",                        [{"name": "COOP_CWK_R1", "type": "bar", "x": ["% nb val >28", "% nb val >29", "% nb val >30", "% nb val >31"], "y": [7, 2, 0, 0]}, {"name": "COOP_ENERC_MEZZ", "type": "bar", "x": ["% nb val >28", "% nb val >29", "% nb val >30", "% nb val >31"], "y": [17, 9, 4, 2]}, {"name": "COOP_ENERC_URSC", "type": "bar", "x": ["% nb val >28", "% nb val >29", "% nb val >30", "% nb val >31"], "y": [14, 6, 2, 1]}, {"name": "COOP_ENER_R2", "type": "bar", "x": ["% nb val >28", "% nb
# ...

# %%
'Moyenne, Maximum, Minimum de Celsius, (03/07 - 31/07), jour (8h-20h), Grenoble' et
'Moyenne, Maximum, Minimum de Celsius, (03/07 - 31/07), nuit (20h-8h), Grenoble'
# Out:
# <div>                            <div id="bf53dc5f-8e51-4985-a3eb-c9aec454a61b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bf53dc5f-8e51-4985-a3eb-c9aec454a61b")) {                    Plotly.newPlot(                        "bf53dc5f-8e51-4985-a3eb-c9aec454a61b",                        [{"name": "avg", "type": "bar", "x": ["COOP_CWK_R1", "COOP_ENERC_MEZZ", "COOP_ENERC_URSC", "COOP_ENER_R2", "COOP_Penishe_R1_su"], "y": [26.8474930362117, 27.003486750348674, 27.002092050209207, 25.928969359331475, 25.941504178272982]}, {"name": "max", "type": "bar", "x": ["COOP_CWK_R1", "COOP_ENERC_MEZZ", "COOP_ENERC_URSC", "COOP_ENER_R2", "COOP_Penishe_R1_su"], "y": [29.5, 32.0, 32.0, 30.0, 28.5]}, {"name": "min", "type": "bar", "x": ["COOP_CWK_R1", "COOP_ENERC_M
# ...

# %%
'Moyenne, Maximum, Minimum de Celsius, (01/08 - 31/08), jour (8h-20h), Grenoble' et
'Moyenne, Maximum, Minimum de Celsius, (01/08 - 31/08), nuit (20h-8h), Grenoble'
# Out:
# <div>                            <div id="648c3729-d3e4-471a-8de7-3f4d8bc3ecf0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("648c3729-d3e4-471a-8de7-3f4d8bc3ecf0")) {                    Plotly.newPlot(                        "648c3729-d3e4-471a-8de7-3f4d8bc3ecf0",                        [{"name": "avg", "type": "bar", "x": ["COOP_CWK_R1", "COOP_ENERC_MEZZ", "COOP_ENERC_URSC", "COOP_ENER_R2", "COOP_Penishe_R1_su"], "y": [26.858709677419355, 26.54193548387097, 26.663225806451614, 25.872258064516128, 25.76129032258065]}, {"name": "max", "type": "bar", "x": ["COOP_CWK_R1", "COOP_ENERC_MEZZ", "COOP_ENERC_URSC", "COOP_ENER_R2", "COOP_Penishe_R1_su"], "y": [30.0, 35.5, 33.0, 31.5, 29.5]}, {"name": "min", "type": "bar", "x": ["COOP_CWK_R1", "COOP_ENERC_M
# ...

# %%
'Moyenne, Maximum, Minimum de Celsius, (01/09 - 30/09), jour (8h-20h), Grenoble' et
'Moyenne, Maximum, Minimum de Celsius, (01/09 - 30/09), nuit (20h-8h), Grenoble'
# Out:
# <div>                            <div id="6afc97e3-096e-4c73-bf59-c1f30663eaae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6afc97e3-096e-4c73-bf59-c1f30663eaae")) {                    Plotly.newPlot(                        "6afc97e3-096e-4c73-bf59-c1f30663eaae",                        [{"name": "avg", "type": "bar", "x": ["COOP_CWK_R1", "COOP_ENERC_MEZZ", "COOP_ENERC_URSC", "COOP_ENER_R2", "COOP_Penishe_R1_su"], "y": [24.128666666666668, 23.407333333333334, 23.64933333333333, 22.66333333333333, 23.288590604026847]}, {"name": "max", "type": "bar", "x": ["COOP_CWK_R1", "COOP_ENERC_MEZZ", "COOP_ENERC_URSC", "COOP_ENER_R2", "COOP_Penishe_R1_su"], "y": [29.0, 27.5, 29.0, 26.5, 26.0]}, {"name": "min", "type": "bar", "x": ["COOP_CWK_R1", "COOP_ENERC_M
# ...
