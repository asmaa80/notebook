# %%
'Moyenne_Taux d’inconfort(Celsius)_Lyon'

# %%
'Moyenne_Taux d’inconfort(Celsius)_Grenoble(Aannée)'

# %%
'Moyenne_Taux d’inconfort(Celsius)_Grenoble(été)'

# %%
import pandas as pd

# %%
from PIL import Image

# %%
# load and show an image with Pillow
from PIL import Image
# load the image
image = Image.open('date.png')
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=541x321 at 0x7FE75E325C70>

# %%
# load and show an image with Pillow
from PIL import Image
# load the image
image = Image.open('Celsius, Grouped by Dates (day) lyon.png')
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1251x572 at 0x7FE75E2190D0>
