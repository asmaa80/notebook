# %% [markdown]
# #                                   'Lyon'

# %%
'date du début' et 'Date de fin'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=561x251 at 0x7F966C08E730>

# %%
'Moyenne, minimum, maximum de degrés Celsius, jour (08_20), Lyon '
'Moyenne, Maximum, Minimum de Celsius, nuit (20_08), Lyon'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1231x672 at 0x7F8220095280>

# %%
'API et Celsius tout le période de travailler jour par jour_Grenoble'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1251x732 at 0x7F82200A5F40>

# %%
'nbval_grenoble' et 'nbval(Celsius)>28'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1101x341 at 0x7F8220065C40>

# %%
'Moyenne_Taux d’inconfort(Celsius)_Lyon'

# %% [markdown]
# #                                'Grenoble'

# %%
'date du début' et 'Date de fin'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=862x341 at 0x7F82200952E0>

# %%
'Moyenne, minimum, maximum de degrés Celsius, jour (08_20), Grenoble '
'Moyenne, Maximum, Minimum de Celsius, nuit (20_08), Grenoble'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1321x921 at 0x7F8220095310>

# %%
'API et Celsius tout le période de travailler jour par jour_Grenoble'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1251x482 at 0x7F8220065430>

# %%
'nbval_grenoble' et 'nbval(Celsius)>28'
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1101x371 at 0x7F8220065F40>

# %%
'Moyenne_Taux d’inconfort(Celsius)_Grenoble(Aannée)'

# %%
'Moyenne_Taux d’inconfort(Celsius)_Grenoble(été)'
